# %%
import pandas as pd
from analysis import *

# Set display options for better readability
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
# PATH of transformed Data
TRANSFORMED_DATA_PATH = r"E:\Python Repo\EDA\data_insights\data\transformed\transformed_data.csv"
df = pd.read_csv(TRANSFORMED_DATA_PATH)

# %%
# STEP 1: Basic data inspection
basic_data_inspection(TRANSFORMED_DATA_PATH)
# Out:
# Basic Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geography        930 non-null    object
#  1   Characteristics  930 non-null    object
#  2   Year             930 non-null    int64
#  3   Value            898 non-null    float64
#  4   Region Type      930 non-null    object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 36.5+ KB
#
# Summary Statistics:
#        Geography             Characteristics         Year          Value  \
# count        930                         930   930.000000     898.000000
# unique        15                           3          NaN            NaN
# top       Canada  Number of new cancer cases          NaN            NaN
# freq          62                         465          NaN            NaN
# ...

# %% [markdown]
# ### Exploratory Data Analysis (EDA) - Cancer Cases Dataset
# **1. Basic Data Inspection**
#
# **Dataset Overview**
# - Total Rows: 930
# - Total Columns: 5
# - Memory Usage: 36.5 KB
#
# **Summary Statistics**
#
# **Year Column**
# - Data is recorded from **1992 to 2022**.
# - The average (**mean**) year is **2007**.
#
# **Value (Cancer Cases)**
# - The **minimum number of cases** recorded is **30**, while the **maximum is 211,510**.
# - The **mean (average) number of cases** is **14,086**.
# - The **median (50%) is 560**, suggesting a **right-skewed distribution**.
# - The **standard deviation is 35,534**, indicating a **wide variation** in case numbers.
#
# **Geography & Region Type**
# - There are **15 unique geographic locations** in the dataset.
# - The most frequent **region type** is **Province/Territory**, appearing **806 times**.
# ---

# %%
# STEP 2: Missing value analysis
missing_values_analysis(df)
# Out:
# Missing Values Count:
# Geography           0
# Characteristics     0
# Year                0
# Value              32
# Region Type         0
# dtype: int64

# %% [markdown]
# **2. Missing Value Analysis**
#
# **Missing Values Count**
# - **Geography:** 0 missing values
# - **Characteristics:** 0 missing values
# - **Year:** 0 missing values
# - **Value:** 32 missing values
# - **Region Type:** 0 missing values
#
# **Interpretation**
# - The **Value** column has **32 missing entries**, meaning that for some records, the number of cancer cases is not available.
# - The **other columns have no missing values**, ensuring that location, year, and region type data are complete.
#
# **Missing Values Heatmap**
# - The **yellow lines in the chart** represent missing values.
# - Missing values **only appear in the `Value` column**.
# - The **Geography, Characteristics, Year, and Region Type columns are complete** (solid purple areas).
# ---

# %%
# STEP 3: Univariate Analysis
univariate_analysis(df)

# %% [markdown]
# **3. Univariate Analysis**
#
# **Trend of New Cancer Cases in Canada (1992-2022)**
# - The first graph shows the **overall trend of new cancer cases in Canada** from **1992 to 2022**.
# - The **number of cases has increased steadily** over time.
# - There is a **sharp increase after 2010**, indicating a **rise in reported cancer cases**.
#
# **Trend of New Cancer Cases Across Provinces (1992-2022)**
# - The second graph represents **individual trends for each province and territory** in Canada.
# - Each **sub-graph** shows the trend of **new cancer cases** for a specific region.
#
# **Key Observations:**
# - **All provinces and territories show an increasing trend**, meaning cancer cases have risen everywhere.
# - **Larger provinces (Ontario, Quebec, Alberta, British Columbia)** have significantly higher cases, likely due to **higher population density**.
# - **Smaller territories (Nunavut, Yukon, Northwest Territories)** have **fewer cases** but still show an increasing trend.
# - A **steeper rise after 2010** in the overall trend might indicate:
#   - **Better cancer detection and reporting**
#   - **An aging population contributing to increased cases**
#   - **Environmental or lifestyle changes leading to a higher incidence of cancer**
# ---

# %%
# STEP 4: Bivariate Analysis
bivariate_analysis(df)
# Out:
# Correlation between Cancer Cases and Incidence Rate: 0.9966732257910795

# %% [markdown]
# **4. Bivariate Analysis**
#
# **Scatter Plot: Cancer Cases vs. Incidence Rate (Canada)**
#
# - This scatter plot examines the relationship between **new cancer cases** and the **cancer incidence rate** in Canada.
# - The **x-axis** represents the **total number of new cancer cases**, while the **y-axis** represents the **cancer incidence rate per 100,000 people (as per standard epidemiological practice)**.
# - The strong **positive linear trend** indicates that as the number of cancer cases increases, the incidence rate also rises.
# - This correlation is expected because **incidence rate is derived from the number of cases per population size**.
#
# **Key Insight:**
# - The **high correlation (0.9967)** between cancer cases and incidence rate suggests that the number of cases is a primary driver of incidence rates, assuming a relatively stable population.
# ---
# **Line Plot: Top 5 Provinces with Highest Cancer Cases (1992-2022)**
#
# - This line graph tracks **cancer case trends** in the **top 5 provinces** from **1992 to 2022**.
# - Each line represents a different **province**, allowing for comparisons in cancer case growth.
#
# **Key Observations:**
# - **Ontario** (red line) has the highest number of cancer cases, showing a **steady increase** over time.
# - **Quebec** (purple line) also has a high number of cases but shows some fluctuations around **2010**.
# - **British Columbia, Alberta, and Manitoba** show **steadily increasing trends**, but at a lower scale.
# - The trends suggest that **cancer cases have been rising consistently across all major provinces**.
#
# ---

# %%
# Multivariate Analysis
multivariate_analysis(df)

# %% [markdown]
# **5. Multivariate Analysis**
#
# **Year-over-Year Growth Rate of Cancer Cases by Region**
#
# This **heatmap** represents the **percentage change** in cancer cases **year-over-year** across different **regions (provinces and territories) from 1992 to 2022**.
#
# **How Was This Growth Rate Calculated?**
# The year-over-year (YoY) growth rate for cancer cases was calculated using the **percentage change formula**:
#
# $$
# \text{Growth Rate (\%)} = \left( \frac{\text{Current Year Cases} - \text{Previous Year Cases}}{\text{Previous Year Cases}} \right) \times 100
# $$
#
# **1️. How to Read This Heatmap**
# - **X-Axis (Columns):** Different regions (Alberta, Ontario, Quebec, etc.).
# - **Y-Axis (Rows):** Years from **1992 to 2022**.
# - **Cell Values:** The **percentage change** in cancer cases from the **previous year**.
#   - **🔵 Blue shades** → **Decrease** in cancer cases compared to the previous year.
#   - **🔴 Red shades** → **Increase** in cancer cases compared to the previous year.
#   - **⚪ White/Light Colors** → **Little or no change** from the previous year.
#
# **2️. Key Observations**
# **Years with Large Increases in Cancer Cases (Red Cells)**
# - **1996 (Northwest Territories: +41.7%)** → A **significant rise** in cancer cases.
# - **1998 (Nunavut: +42.9%, 1999 Prince Edward Island: +46.2%)** → Another **huge jump**.
# - **2007 (Northwest Territories: +28.6%)** → A major spike in cancer cases in **Northwest Territories**.
# - **2009 (Yukon: +52.6%)** → **Highest recorded increase in the dataset**.
# - **2017, 2022 (Nunavut: +28.6%)** → Another peak year for cancer cases in **Nunavut**.
# - **2022 (Yukon: +44.8%)** → A recent sharp increase in Yukon.
#
# **Years with Large Decreases in Cancer Cases (Blue Cells)**
# - **1994 (Nunavut: -25.0%), 2018 (Nunavut: -22.2%)** → A sharp **drop in cancer cases**.
# - **2003 (Yukon: -26.1%)** → Major **reduction** in cases.
# - **2008 (Northwest Territories: -22.2%), 2020 (Northwest Territories: -21.1)** → A **significant decrease** in cases.
#
# **Possible Reasons for These Changes**
# - **Sharp increases in some provinces (e.g., Newfoundland & Labrador, Nunavut, Yukon)**
#   - Could be due to **improved cancer detection/screening programs**.
#   - **Population changes** (e.g., more elderly people in the province).
#   - **Environmental or lifestyle factors** affecting specific regions.
#
# - **Sharp decreases in some years (e.g., 1994, 2003, 2008, 2018, 2020)**
#   - Could be due to **improvements in cancer prevention**.
#   - **Temporary drop in reported cases** (e.g., changes in reporting policies).
